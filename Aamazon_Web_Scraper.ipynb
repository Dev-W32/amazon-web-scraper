# %% [markdown]
# <a href="https://colab.research.google.com/github/Dev-W32/amazon-web-scraper/blob/main/Aamazon_Web_Scraper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
import urllib
import csv
import json

# %%
asin=''
prodDesc=''
def generateDict(soup,a_tag,price):
  dataDict={}
  for i in a_tag:
        text.append(i.text)
        href.append(i['href'])
        url = i['href']
        url = url.split("&url=")[-1]
        amazon_url="https://www.amazon.in" + urllib.parse.unquote(url)
        dataDict[i.text]={'title':i.text,'url':amazon_url,'price':0,'noOfRatings':0,'ratings':'',asin:'',prodDesc:''}
        

  return dataDict

# %%
import re
fieldnames=['Title','URL','Price','Rating','Number of Ratings']
def writeFile(dataDict):
  with open('data.csv', 'a', newline='',encoding='utf-8') as f:
        writer = csv.DictWriter(f, fieldnames=['Title','URL','Price','Rating','Number of Ratings'])
        for i in dataDict:
            iurl=dataDict[i]['url']
            urlSoup = requests.get(iurl,headers=HEADERS)
            newSoup = BeautifulSoup(urlSoup.text,"html.parser",from_encoding="utf-8")
            price=newSoup.find('span',{'class':'a-offscreen'}).text
            rating=newSoup.find('span',{'id':'acrPopover'}).text
            noOfRatings=newSoup.find('span',{'id':'acrCustomerReviewText'}).text
            dataDict[i]['price']=price
            dataDict[i]['noOfRatings']=noOfRatings
            dataDict[i]['ratings']=rating
            row={'Title':i,'URL':iurl,'Price':price,'Rating':str(rating),'Number of Ratings':noOfRatings}
            writer.writerow(row)
            print(iurl,'\t',price,'\t',rating,'\t',noOfRatings)
            print('\n\n\n')

# %%
dataDict={}
for x in range(1,20):
    HEADERS = {
    'User-Agent': ('Mozilla/5.0 (X11; Linux x86_64)'
                    'AppleWebKit/537.36 (KHTML, like Gecko)'
                    'Chrome/44.0.2403.157 Safari/537.36'),
    'Accept-Language': 'en-US, en;q=0.5'
}


    url = f"https://www.amazon.in/s?k=bags&page={x}"
    html = requests.get(url)
    soup = BeautifulSoup(html.text,"html.parser")
    removal_content = [
    
    soup.find('header',{'class':'nav-opt-sprite nav-flex nav-locale-in nav-lang-en nav-ssl nav-unrec nav-progressive-attribute'}),

        soup.find('div',{'class':['s-result-item s-widget s-widget-spacing-large AdHolder s-flex-full-width','sg-col-4-of-24 sg-col-4-of-12 s-matching-dir sg-col-4-of-16 sg-col sg-col-4-of-20','a-section sbv-video-overlay']})
    ]
    
    for i in removal_content:
        if i :
            i.extract()
        else:
            print('Nothing to remove')
            

    text=[]
    href=[]
    amazon_url=[]
    a_tag = soup.find_all('a', {'class': 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal'})

    price = soup.find_all('span',{'class':'a-price a-text-price'})
    dataDict=generateDict(soup,a_tag,price)
    writeFile(dataDict)
# Out:
# Nothing to remove
# Nothing to remove
# Nothing to remove
# Nothing to remove
# Nothing to remove
# Nothing to remove
# /usr/local/lib/python3.8/dist-packages/bs4/__init__.py:179: UserWarning: You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.
#   warnings.warn("You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.")
# https://www.amazon.in/YuvKuz-TM-Infocus-Digitizer-Assembly/dp/B07MXNWTB2 	 ₹824.00
#   4.2 out of 5 stars     	 7,320 ratings
#
#
#
#
# https://www.amazon.in/PETRICE-Multifunctional-Travel-Makeup-Organiser/dp/B07W22LC2D 	 ₹499.00
#   4.2 out of 5 stars     	 1,772 ratings
#
#
#
#
# https://www.amazon.in/Baggit-Womens-Satchel-Handbag-Grey/dp/B098TKJG1L 	 ₹666
#   4.3 out of 5 stars     	 780 ratings
#
#
#
#
# https://www.amazon.in/Gear-Beige-Casual-Backpack-BKPTRMP520522/dp/B00VWM11HQ 	 ₹799.00
#   4.2 out of 5 stars     	 5,377 ratings
#
#
#
#
# https://www.amazon.in/Wesley-Briefcase-Professional-Messenger-Resistant/dp/B08K7PN23C 	 ₹498.00
#   4.0 out of 5 stars     	 1,065 ratings
#
#
#
#
# https://www.amazon.in/Chic-Buddy-Waterproof-Swimsuits-Toiletries/dp/B09KSBHC18 	 ₹299
#   4.5 out of 5 stars     	 257 ratings
#
#
#
#
# https://www.amazon.in/Fostelo-CATLIN-Womens-Handbag-Maroon/dp/B079MD5F7R 	 ₹498.00
#   4.1 out of 5 stars     	 8,913 ratings
#
#
#
#
# https://www.amazon.in/Amazon-Brand-Womens-Sling-Mustard/dp/B07XBZR7SR 	 ₹599
#   4.1 out of 5 stars     	 559 ratings
#
#
#
#
# https://www.amazon.in/TULMAN-Stylish-Messenger-Shoulder-Bag/dp/B07Q74QLHT 	 ₹799
#   4.1 out of 5 stars     	 366 ratings
#
#
#
#
# https://www.amazon.in/Asus-BP1504-15-6-inch-Laptop-Backpack/dp/B0895ZZHKK 	 ₹766.00
#   4.2 out of 5 stars     	 1,482 ratings
#
#
#
#
# https://www.amazon.in/American-Tourister-Polypropylene-LG4-002_Crimson/dp/B0BB2LKNXG 	 ₹2,699.00
#   4.2 out of 5 stars     	 123 ratings
#
#
#
#
# https://www.amazon.in/Lenovo-Laptop-Backpack-15-6-Inch-GX40Q17225/dp/B075Y72PHZ 	 ₹1,011.00
#   4.2 out of 5 stars     	 53,084 ratings
#
#
#
#
# https://www.amazon.in/ALIZA-Womens-Tote-Bag-Black/dp/B08JJ8RQNR 	 ₹403
#   4.0 out of 5 stars     	 7,631 ratings
#
#
#
#
# https://www.amazon.in/Tabelito-Office-Laptop-Briefcase-Women/dp/B08FKXCJNQ 	 ₹549
#   4.0 out of 5 stars     	 2,372 ratings
#
#
#
#
# https://www.amazon.in/Baggit-Womens-Hobo-Handbag-Green/dp/B097C2T2DS 	 ₹528.00
#   4.4 out of 5 stars     	 1,927 ratings
#
#
#
#
# https://www.amazon.in/BennettTM-Mystic-Shoulder-Messenger-Repellent/dp/B09321GJXZ 	 ₹512.00
#   4.1 out of 5 stars     	 4,862 ratings
#
#
#
#
# Nothing to remove
# Nothing to remove
# Nothing to remove
# Nothing to remove
# Nothing to remove
# Nothing to remove
# https://www.amazon.in/Leatherette-Executive-messenger-multiple-compartments/dp/B099NM8621 	 ₹938.00
#   3.9 out of 5 stars     	 337 ratings
#
#
#
#
# https://www.amazon.in/American-Tourister-27O-70-003/dp/B073XL19QZ 	 ₹4,799
#   4.3 out of 5 stars     	 5,236 ratings
#
#
#
#
# https://www.amazon.in/ADISA-SL5038-women-girls-sling/dp/B08Q4FHQLN 	 ₹575.00
#   4.0 out of 5 stars     	 2,561 ratings
#
#
#
#
# https://www.amazon.in/Red-Lemon-Polyester-15-6-inch-Waterproof/dp/B07XYY2FW4 	 ₹2,849.00
#   4.2 out of 5 stars     	 152 ratings
#
#
#
#
# https://www.amazon.in/Baggit-Womens-Sling-Bag-Small/dp/B0BNTQLVBF 	 ₹700.00
#   5.0 out of 5 stars     	 1 rating
#
#
#
#
# https://www.amazon.in/ADISA-SL5022-black-women-girls/dp/B07NPXWFXX 	 ₹495.00
#   4.1 out of 5 stars     	 2,772 ratings
#
#
#
#
# https://www.amazon.in/Wesley-Milestone-Waterproof-Backpack-Business/dp/B07NJRPJ6Q 	 ₹498.00
#   4.3 out of 5 stars     	 12,106 ratings
#
#
#
#
# https://www.amazon.in/ZIBUYU®-Handbag-Fashion-Shoulder-Crossbody/dp/B0B3MTSRFK 	 ₹1,322
#   3.9 out of 5 stars     	 39 ratings
#
#
#
#
# https://www.amazon.in/Chic-Buddy-Waterproof-Swimsuits-Toiletries/dp/B0B25B5PB6 	 ₹279
#   4.5 out of 5 stars     	 257 ratings
#
#
#
#
# https://www.amazon.in/Tabelito-Laptop-Backpack-15-6-inch-Repellent/dp/B08Y3L4PHK 	 ₹549.00
#   4.2 out of 5 stars     	 1,499 ratings
#
#
#
#
# https://www.amazon.in/BROGBUS-Business-Messenger-Sling-10-05inch/dp/B09QLD9GJY 	 ₹989
#   4.1 out of 5 stars     	 368 ratings
#
#
#
#
# https://www.amazon.in/Isle-Locada-Hidesign-Womens-Sling/dp/B07TDTPRJ9 	 ₹1,899.00
#   4.5 out of 5 stars     	 353 ratings
#
#
#
#
# https://www.amazon.in/ADISA-Womens-Sling-SL5059-CRE_Off-White/dp/B09154JPWQ 	 ₹495
#   4.1 out of 5 stars     	 2,147 ratings
#
#
#
#
# https://www.amazon.in/Wooum-Business-Messenger-Shoulder-9x3-56inch/dp/B09KV1PFHV 	 ₹328
#   4.0 out of 5 stars     	 1,172 ratings
#
#
#
#
# https://www.amazon.in/Wildcraft-Turnaround-Polyester-Laptop-8903340000000/dp/B012D4QWES 	 ₹1,695.00
#   4.3 out of 5 stars     	 3,184 ratings
#
#
#
#
# Nothing to remove
# Nothing to remove
# Nothing to remove
# Nothing to remove
# Nothing to remove
# Nothing to remove
# Nothing to remove
# Nothing to remove
# Nothing to remove
# Nothing to remove
# Nothing to remove
# Nothing to remove
# Nothing to remove
# Nothing to remove
# Nothing to remove
# Nothing to remove
# Nothing to remove
# Nothing to remove
# Nothing to remove
# Nothing to remove
# Nothing to remove
# Nothing to remove
